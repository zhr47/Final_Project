# %%
import pandas as pd
import numpy as np
from numpy import *
from math import nan

# %%
df = pd.read_csv("data/listings.csv")
df
# Out:
#              id                            listing_url     scrape_id  \
# 0          2818      https://www.airbnb.com/rooms/2818  2.020100e+13
# 1         20168     https://www.airbnb.com/rooms/20168  2.020100e+13
# 2         25428     https://www.airbnb.com/rooms/25428  2.020100e+13
# 3         27886     https://www.airbnb.com/rooms/27886  2.020100e+13
# 4         28871     https://www.airbnb.com/rooms/28871  2.020100e+13
# ...         ...                                    ...           ...
# 18777  45761390  https://www.airbnb.com/rooms/45761390  2.020100e+13
# 18778  45763935  https://www.airbnb.com/rooms/45763935  2.020100e+13
# 18779  45776325  https://www.airbnb.com/rooms/45776325  2.020100e+13
# 18780  45777642  https://www.airbnb.com/rooms/45777642  2.020100e+13
# 18781  45783000  https://www.airbnb.com/rooms/45783000  2.020100e+13
#
#       last_scraped                                               name  \
# 0         10/11/20           Quiet Garden View Room & Super Fast WiFi
# 1         10/11/20       Studio with private bathroom in the centre 1
# 2         10/11/20    Lovely apt in City Centre (w.lift) near Jordaan
# 3         10/10/20  Romantic, stylish B&B houseboat in canal district
# 4         10/10/20                            Comfortable double room
# ...            ...                                                ...
# 18777     10/10/20              Charming 1Room Apartment in Amsterdam
# 18778     10/10/20         clean and light apartment nearby the water
# 18779     10/13/20   A beautiful spacious room on a central location.
# 18780     10/13/20                                Studio in Amsterdam
# 18781     10/10/20             Spacious and cozy apartment in De Pijp
#
#                                              description  \
# 0      Quiet Garden View Room & Super Fast WiFi<br />...
# 1      17th century Dutch townhouse in the heart of t...
# 2      Lovely apt in Centre ( lift & fireplace) near ...
# 3      Stylish and romantic houseboat on fantastic hi...
# 4      <b>The space</b><br />In a monumental house ri...
# ...                                                  ...
# 18777  Nice flat in the ground floor in the west area...
# 18778                      Very clean and tidy apartment
# 18779                                                NaN
# 18780  Hello!<br />My room is free for 2 weeks Octobe...
# 18781  Located in the heart of Amsterdam, in a peacef...
#
#                                    neighborhood_overview  \
# 0      Indische Buurt ("Indies Neighborhood") is a ne...
# 1      Located just in between famous central canals....
# 2                                                    NaN
# 3             Central, quiet, safe, clean and beautiful.
# 4           Flower market , Leidseplein , Rembrantsplein
# ...                                                  ...
# 18777                                                NaN
# 18778                                                NaN
# 18779                                                NaN
# 18780                                                NaN
# 18781                                                NaN
#
#                                              picture_url    host_id  \
# 0      https://a0.muscache.com/pictures/10272854/8dcc...       3159
# 1      https://a0.muscache.com/pictures/69979628/fd6a...      59484
# 2      https://a0.muscache.com/pictures/138431/7079a9...      56142
# 3      https://a0.muscache.com/pictures/02c2da9d-660e...      97647
# 4      https://a0.muscache.com/pictures/160889/362340...     124245
# ...                                                  ...        ...
# 18777  https://a0.muscache.com/pictures/766447f8-1ec7...  310835509
# 18778  https://a0.muscache.com/pictures/8b4d4ef5-8b9f...     961670
# 18779  https://a0.muscache.com/pictures/4339516f-0f3b...   48168060
# 18780  https://a0.muscache.com/pictures/2ef85d3f-9c1e...   75268907
# 18781  https://a0.muscache.com/pictures/adfb4e2b-2428...  371160113
#
#                                           host_url  ...  \
# 0           https://www.airbnb.com/users/show/3159  ...
# 1          https://www.airbnb.com/users/show/59484  ...
# 2          https://www.airbnb.com/users/show/56142  ...
# 3          https://www.airbnb.com/users/show/97647  ...
# 4         https://www.airbnb.com/users/show/124245  ...
# ...                                            ...  ...
# 18777  https://www.airbnb.com/users/show/310835509  ...
# 18778     https://www.airbnb.com/users/show/961670  ...
# 18779   https://www.airbnb.com/users/show/48168060  ...
# 18780   https://www.airbnb.com/users/show/75268907  ...
# 18781  https://www.airbnb.com/users/show/371160113  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            10.0                    9.0                10.0
# 1                            10.0                   10.0                 9.0
# 2                            10.0                   10.0                10.0
# 3                            10.0                   10.0                10.0
# 4                            10.0                   10.0                10.0
# ...                           ...                    ...                 ...
# 18777                         NaN                    NaN                 NaN
# 18778                         NaN                    NaN                 NaN
# 18779                         NaN                    NaN                 NaN
# 18780                         NaN                    NaN                 NaN
# 18781                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 0         NaN                t                              1
# 1         NaN                t                              2
# 2         NaN                f                              1
# 3         NaN                t                              1
# 4         NaN                f                              2
# ...       ...              ...                            ...
# 18777     NaN                t                              1
# 18778     NaN                f                              2
# 18779     NaN                f                              2
# 18780     NaN                f                              1
# 18781     NaN                t                              1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               0
# 1                                               0
# 2                                               1
# 3                                               0
# 4                                               0
# ...                                           ...
# 18777                                           1
# 18778                                           2
# 18779                                           0
# 18780                                           1
# 18781                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                1
# 1                                                2
# 2                                                0
# 3                                                1
# 4                                                2
# ...                                            ...
# 18777                                            0
# 18778                                            0
# 18779                                            2
# 18780                                            0
# 18781                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              1.98
# 1                                               0              2.63
# 2                                               0              0.15
# 3                                               0              2.05
# 4                                               0              2.72
# ...                                           ...               ...
# 18777                                           0               NaN
# 18778                                           0               NaN
# 18779                                           0               NaN
# 18780                                           0               NaN
# 18781                                           0               NaN
#
# [18782 rows x 74 columns]

# %%
df.host_is_superhost = df.host_is_superhost.str.replace("f","0")
df.host_is_superhost = df.host_is_superhost.str.replace("t","1")
df.host_identity_verified = df.host_identity_verified.str.replace("f","0")
df.host_identity_verified = df.host_identity_verified.str.replace("t","1")
df.instant_bookable = df.instant_bookable.str.replace("f","0")
df.instant_bookable = df.instant_bookable.str.replace("t","1")
df['amenities_count'] = df.amenities.str.count(',')

# %%
df_simple = df[[
    'id',
    'host_is_superhost',
    'host_identity_verified',
    'bedrooms',
    'beds',
    'accommodates',
    'number_of_reviews',
    'review_scores_rating',
    'reviews_per_month',
    'amenities_count',
    'host_listings_count',
    'instant_bookable',
    'reviews_per_month',
    'price',]]
df_simple
# Out:
#              id host_is_superhost host_identity_verified  bedrooms  beds  \
# 0          2818                 1                      1       1.0   2.0
# 1         20168                 0                      1       1.0   1.0
# 2         25428                 1                      0       1.0   1.0
# 3         27886                 1                      1       1.0   1.0
# 4         28871                 1                      1       1.0   1.0
# ...         ...               ...                    ...       ...   ...
# 18777  45761390                 0                      1       1.0   2.0
# 18778  45763935                 0                      0       2.0   0.0
# 18779  45776325                 0                      0       1.0   1.0
# 18780  45777642                 0                      0       1.0   0.0
# 18781  45783000                 0                      1       1.0   1.0
#
#        accommodates  number_of_reviews  review_scores_rating  \
# 0                 2                278                  98.0
# 1                 2                340                  89.0
# 2                 3                  5                 100.0
# 3                 2                219                  99.0
# 4                 2                336                  97.0
# ...             ...                ...                   ...
# 18777             4                  0                   NaN
# 18778             1                  0                   NaN
# 18779             2                  0                   NaN
# 18780             2                  0                   NaN
# 18781             2                  0                   NaN
#
#        reviews_per_month  amenities_count  host_listings_count  \
# 0                   1.98               25                  1.0
# 1                   2.63               16                  2.0
# 2                   0.15               28                  2.0
# 3                   2.05               23                  1.0
# 4                   2.72               14                  2.0
# ...                  ...              ...                  ...
# 18777                NaN                8                892.0
# 18778                NaN               10                  2.0
# 18779                NaN               19                  3.0
# 18780                NaN                8                  0.0
# 18781                NaN               25                  1.0
#
#       instant_bookable  reviews_per_month     price
# 0                    1               1.98   $59.00
# 1                    1               2.63  $236.00
# 2                    0               0.15  $125.00
# 3                    1               2.05  $138.00
# 4                    0               2.72   $75.00
# ...                ...                ...       ...
# 18777                1                NaN  $137.00
# 18778                0                NaN  $120.00
# 18779                0                NaN   $20.00
# 18780                0                NaN   $33.00
# 18781                1                NaN  $105.00
#
# [18782 rows x 14 columns]

# %%
df_simple = df_simple.fillna(0)

# %%
df_complex = df[['id',
         'host_is_superhost',
         'host_neighbourhood',
         'neighbourhood',
         'neighbourhood_cleansed',
         'latitude',
         'longitude',
         'property_type',
         'room_type',
         'accommodates',
         'bathrooms_text',
         'bedrooms',
         'beds',
         'amenities',
         'price',
         'number_of_reviews',
         'review_scores_rating',
         'review_scores_location'                   
                     ]]

# %%
#df_amenities = df[0:9,:]
#df_amenities.head()

# %%
#for listing in df_amenities[0:9,:]:
#    for amenity in df_amenities.amenities:
#        df_amenities[amenity] = 0
        # df_amenities.iloc[listing,amenity] = 1

# %%
df_simple.to_csv(r'data/simple_data_for_ML.csv')

# %%
df_simple
# Out:
#              id host_is_superhost host_identity_verified  bedrooms  beds  \
# 0          2818                 1                      1       1.0   2.0
# 1         20168                 0                      1       1.0   1.0
# 2         25428                 1                      0       1.0   1.0
# 3         27886                 1                      1       1.0   1.0
# 4         28871                 1                      1       1.0   1.0
# ...         ...               ...                    ...       ...   ...
# 18777  45761390                 0                      1       1.0   2.0
# 18778  45763935                 0                      0       2.0   0.0
# 18779  45776325                 0                      0       1.0   1.0
# 18780  45777642                 0                      0       1.0   0.0
# 18781  45783000                 0                      1       1.0   1.0
#
#        accommodates  number_of_reviews  review_scores_rating  \
# 0                 2                278                  98.0
# 1                 2                340                  89.0
# 2                 3                  5                 100.0
# 3                 2                219                  99.0
# 4                 2                336                  97.0
# ...             ...                ...                   ...
# 18777             4                  0                   0.0
# 18778             1                  0                   0.0
# 18779             2                  0                   0.0
# 18780             2                  0                   0.0
# 18781             2                  0                   0.0
#
#        reviews_per_month  amenities_count  host_listings_count  \
# 0                   1.98               25                  1.0
# 1                   2.63               16                  2.0
# 2                   0.15               28                  2.0
# 3                   2.05               23                  1.0
# 4                   2.72               14                  2.0
# ...                  ...              ...                  ...
# 18777               0.00                8                892.0
# 18778               0.00               10                  2.0
# 18779               0.00               19                  3.0
# 18780               0.00                8                  0.0
# 18781               0.00               25                  1.0
#
#       instant_bookable  reviews_per_month     price
# 0                    1               1.98   $59.00
# 1                    1               2.63  $236.00
# 2                    0               0.15  $125.00
# 3                    1               2.05  $138.00
# 4                    0               2.72   $75.00
# ...                ...                ...       ...
# 18777                1               0.00  $137.00
# 18778                0               0.00  $120.00
# 18779                0               0.00   $20.00
# 18780                0               0.00   $33.00
# 18781                1               0.00  $105.00
#
# [18782 rows x 14 columns]
