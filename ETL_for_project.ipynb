# %%
import pandas as pd
import numpy as np
from numpy import *
from math import nan

# %%
df=pd.read_csv("data/listings.csv")

# %%
df = df[['id',
         'host_is_superhost',
         'host_neighbourhood',
         'neighbourhood',
         'neighbourhood_cleansed',
         'latitude',
         'longitude',
         'property_type',
         'room_type',
         'accommodates',
         'bathrooms_text',
         'bedrooms',
         'beds',
         'amenities',
         'price',
         'number_of_reviews',
         'review_scores_rating',
         'review_scores_location'                   
                     ]]

# %%
df = df.fillna(0)

# %%
df.head()
# Out:
#       id host_is_superhost   host_neighbourhood  \
# 0   2818                 t       Indische Buurt
# 1  20168                 f       Grachtengordel
# 2  25428                 t       Grachtengordel
# 3  27886                 t  Westelijke Eilanden
# 4  28871                 t    Amsterdam Centrum
#
#                            neighbourhood  \
# 0  Amsterdam, North Holland, Netherlands
# 1  Amsterdam, North Holland, Netherlands
# 2                                      0
# 3  Amsterdam, North Holland, Netherlands
# 4  Amsterdam, North Holland, Netherlands
#
#                    neighbourhood_cleansed  latitude  longitude  \
# 0  Oostelijk Havengebied - Indische Buurt  52.36575    4.94142
# 1                            Centrum-Oost  52.36424    4.89396
# 2                            Centrum-West  52.37297    4.88339
# 3                            Centrum-West  52.38761    4.89188
# 4                            Centrum-West  52.36719    4.89092
#
# ...

# %%
len(df)
# Out:
# 18782

# %%
df['amenities_count'] = df.amenities.str.count(',')

# %%
df.head()
# Out:
#       id host_is_superhost   host_neighbourhood  \
# 0   2818                 t       Indische Buurt
# 1  20168                 f       Grachtengordel
# 2  25428                 t       Grachtengordel
# 3  27886                 t  Westelijke Eilanden
# 4  28871                 t    Amsterdam Centrum
#
#                            neighbourhood  \
# 0  Amsterdam, North Holland, Netherlands
# 1  Amsterdam, North Holland, Netherlands
# 2                                      0
# 3  Amsterdam, North Holland, Netherlands
# 4  Amsterdam, North Holland, Netherlands
#
#                    neighbourhood_cleansed  latitude  longitude  \
# 0  Oostelijk Havengebied - Indische Buurt  52.36575    4.94142
# 1                            Centrum-Oost  52.36424    4.89396
# 2                            Centrum-West  52.37297    4.88339
# 3                            Centrum-West  52.38761    4.89188
# 4                            Centrum-West  52.36719    4.89092
#
# ...

# %%
df.to_csv(r'data\data_for_ML.csv')
